# %%
import gym

env = gym.make("Taxi-v3", render_mode="rgb_array")
env.reset()
print(env.P[328])
env.env.s = 444
for i in range(10):
    #env.render()
    move = env.action_space.sample()
    env.step(move)
# Out:
# {0: [(1.0, 428, -1, False)], 1: [(1.0, 228, -1, False)], 2: [(1.0, 348, -1, False)], 3: [(1.0, 328, -1, False)], 4: [(1.0, 328, -10, False)], 5: [(1.0, 328, -10, False)]}

# %%
observation, reward, terminated, trunkaced, info= env.step(0)

# %%
env.reset()[0]
# Out:
# 262

# %%
import numpy as np

q_table = np.zeros([env.observation_space.n, env.action_space.n])

q_table.shape
# Out:
# (500, 6)

# %%
max(q_table[328])
# Out:
# 0.0

# %%
import random

# Hyperparameters
alpha = 0.1
gamma = 0.6
epsilon = 0.1

# %%
# For plotting metrics
all_epochs = []
all_penalties = []
for i in range(1, 10):
    state = env.reset()[0]
    epochs, penalties, reward, = (
        0,
        0,
        0,
    )
    truncated, terminated = False, False
    while not truncated and not terminated:
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample()  # Explore action space
        else:
            action = np.argmax(q_table[state])  # Exploit learned values
        (
            next_state,
            reward,
            truncated,
            terminated,
            info,
        ) = env.step(action)

        old_value = q_table[state, action]
        next_max = np.max(q_table[next_state])  
        env.render()
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state, action] = new_value
    if reward == -10:
        penalties += 1
    state = next_state
    epochs += 1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\miskibin\Desktop\rl_lawryn\env\lib\site-packages\gym\envs\toy_text\taxi.py:294, in TaxiEnv._render_gui(self, mode)
#     293 try:
# --> 294     import pygame  # dependency to pygame only if rendering with human
#     295 except ImportError:
#
# ModuleNotFoundError: No module named 'pygame'
#
# During handling of the above exception, another exception occurred:
#
# DependencyNotInstalled                    Traceback (most recent call last)
# Cell In[35], line 27
#      25 old_value = q_table[state, action]
#      26 next_max = np.max(q_table[next_state])
# ---> 27 env.render()
#      28 new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
#      29 q_table[state, action] = new_value
#
# File c:\Users\miskibin\Desktop\rl_lawryn\env\lib\site-packages\gym\core.py:329, in Wrapper.render(self, *args, **kwargs)
#     325 def render(
#     326     self, *args, **kwargs
#     327 ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328     """Renders the environment."""
# --> 329     return self.env.render(*args, **kwargs)
#
# File c:\Users\miskibin\Desktop\rl_lawryn\env\lib\site-packages\gym\wrappers\order_enforcing.py:51, in OrderEnforcing.render(self, *args, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(*args, **kwargs)
#
# File c:\Users\miskibin\Desktop\rl_lawryn\env\lib\site-packages\gym\wrappers\env_checker.py:53, in PassiveEnvChecker.render(self, *args, **kwargs)
#      51 if self.checked_render is False:
#      52     self.checked_render = True
# ---> 53     return env_render_passive_checker(self.env, *args, **kwargs)
#      54 else:
#      55     return self.env.render(*args, **kwargs)
#
# File c:\Users\miskibin\Desktop\rl_lawryn\env\lib\site-packages\gym\utils\passive_env_checker.py:316, in env_render_passive_checker(env, *args, **kwargs)
#     310     else:
#     311         assert env.render_mode is None or env.render_mode in render_modes, (
#     312             "The environment was initialized successfully however with an unsupported render mode. "
#     313             f"Render mode: {env.render_mode}, modes: {render_modes}"
#     314         )
# --> 316 result = env.render(*args, **kwargs)
#     318 # TODO: Check that the result is correct
#     320 return result
#
# File c:\Users\miskibin\Desktop\rl_lawryn\env\lib\site-packages\gym\envs\toy_text\taxi.py:290, in TaxiEnv.render(self)
#     288     return self._render_text()
#     289 else:  # self.render_mode in {"human", "rgb_array"}:
# --> 290     return self._render_gui(self.render_mode)
#
# File c:\Users\miskibin\Desktop\rl_lawryn\env\lib\site-packages\gym\envs\toy_text\taxi.py:296, in TaxiEnv._render_gui(self, mode)
#     294     import pygame  # dependency to pygame only if rendering with human
#     295 except ImportError:
# --> 296     raise DependencyNotInstalled(
#     297         "pygame is not installed, run `pip install gym[toy_text]`"
#     298     )
#     300 if self.window is None:
#     301     pygame.init()
#
# DependencyNotInstalled: pygame is not installed, run `pip install gym[toy_text]`
